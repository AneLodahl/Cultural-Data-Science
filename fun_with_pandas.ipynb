# %% [markdown]
# # Lab 03: Fun with `pandas`!

# %% [markdown]
# Below are some exercises to get you working with `pandas` to manipulate data. As always, get as far as you can, and ask for help when you need it! Your teacher (me), you instructor, and your classmates are all here to help each other get better at coding. Getting the code to work is important, but do also take the time to make sure you understand what the commands are doing. This time, (with the exception of the Stroop challenge), all I've given you is the code to download the data. Then you are on your own. For the Stroop challenge, I gave the you code for the first step—after that, it's up to you :-)

# %% [markdown]
# ## Music sales challenge
#
# Write a script that:
#
# 1. Combines the tables of best-selling physical singles and best-selling digital singles on the Wikipedia page "List_of_best-selling_singles"
# 2. Adds a column which marks whether each row is from the list of physical singles or digital singles
# 3. Outputs the artist and single name for the year you were born. If there is no entry for that year, take the closest year after you were born.
# 4. Outputs the artist and single name for the year you were 15 years old.

# %%
# Starter code...

# %pip install lxml
import pandas as pd

rawdata = pd.read_html("https://en.wikipedia.org/wiki/List_of_best-selling_singles")
# Out:
# Collecting lxml
#   Downloading lxml-5.3.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Downloading lxml-5.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 16.4 MB/s eta 0:00:0000:01
# Installing collected packages: lxml
# Successfully installed lxml-5.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#table for physical
df_physical = rawdata[0]
df_physical
# Out:
#                                   Artist  \
# 0                            Bing Crosby
# 1                             Elton John
# 2                            Bing Crosby
# 3                             Tino Rossi
# 4                Bill Haley & His Comets
# 5                        Whitney Houston
# 6                          Elvis Presley
# 7                         USA for Africa
# 8                          The Ink Spots
# 9                            Celine Dion
# 10                          Mariah Carey
# 11                               Baccara
# 12                           Bryan Adams
# 13  John Travolta and Olivia Newton-John
#
#                                                Single  Released  \
# 0                                   "White Christmas"      1942
# 1   "Something About the Way You Look Tonight"/"Ca...      1997
# 2                                      "Silent Night"      1935
# 3                                   "Petit Papa Noël"      1946
# 4                             "Rock Around the Clock"      1954
# 5                            "I Will Always Love You"      1992
# 6                                 "It's Now or Never"      1960
# 7                                  "We Are the World"      1985
# 8                                  "If I Didn't Care"      1939
# 9                               "My Heart Will Go On"      1997
# 10                  "All I Want For Christmas Is You"      1994
# 11                            "Yes Sir, I Can Boogie"      1977
# 12                "(Everything I Do) I Do It for You"      1991
# 13                       "You're the One That I Want"      1978
#
#        Sales (in millions)  Source
# 0                       50     [1]
# 1                       33     [1]
# 2                       30     [2]
# 3                       30     [3]
# 4                       25  [4][5]
# 5                       24  [6][7]
# 6                       20  [8][9]
# 7                       20    [10]
# 8   19[disputed – discuss]    [11]
# 9                       18    [12]
# 10                      16    [13]
# 11                      16    [14]
# 12                      15    [15]
# 13                      15    [16]

# %%
#add column for physical

df_physical['Phy/Dig'] = pd.Series(['Physical' for x in range(len(df_physical.index))])
df_physical
# Out:
#                                   Artist  \
# 0                            Bing Crosby
# 1                             Elton John
# 2                            Bing Crosby
# 3                             Tino Rossi
# 4                Bill Haley & His Comets
# 5                        Whitney Houston
# 6                          Elvis Presley
# 7                         USA for Africa
# 8                          The Ink Spots
# 9                            Celine Dion
# 10                          Mariah Carey
# 11                               Baccara
# 12                           Bryan Adams
# 13  John Travolta and Olivia Newton-John
#
#                                                Single  Released  \
# 0                                   "White Christmas"      1942
# 1   "Something About the Way You Look Tonight"/"Ca...      1997
# 2                                      "Silent Night"      1935
# 3                                   "Petit Papa Noël"      1946
# 4                             "Rock Around the Clock"      1954
# 5                            "I Will Always Love You"      1992
# 6                                 "It's Now or Never"      1960
# 7                                  "We Are the World"      1985
# 8                                  "If I Didn't Care"      1939
# 9                               "My Heart Will Go On"      1997
# 10                  "All I Want For Christmas Is You"      1994
# 11                            "Yes Sir, I Can Boogie"      1977
# 12                "(Everything I Do) I Do It for You"      1991
# 13                       "You're the One That I Want"      1978
#
#        Sales (in millions)  Source   Phy/Dig
# 0                       50     [1]  Physical
# 1                       33     [1]  Physical
# 2                       30     [2]  Physical
# 3                       30     [3]  Physical
# 4                       25  [4][5]  Physical
# 5                       24  [6][7]  Physical
# 6                       20  [8][9]  Physical
# 7                       20    [10]  Physical
# 8   19[disputed – discuss]    [11]  Physical
# 9                       18    [12]  Physical
# 10                      16    [13]  Physical
# 11                      16    [14]  Physical
# 12                      15    [15]  Physical
# 13                      15    [16]  Physical

# %%
df_digital = rawdata[3]
df_digital
# Out:
#                                  Artist                      Single  Released  \
# 0                            Ed Sheeran              "Shape of You"      2017
# 1     Luis Fonsi featuring Daddy Yankee                 "Despacito"      2017
# 2               Rihanna featuring Drake                      "Work"      2016
# 3         The Chainsmokers and Coldplay  "Something Just Like This"      2017
# 4                            Ed Sheeran                   "Perfect"      2017
# 5    Wiz Khalifa featuring Charlie Puth             "See You Again"      2015
# 6     The Chainsmokers featuring Halsey                    "Closer"      2016
# 7                                 Adele       "Rolling in the Deep"      2011
# 8      Mark Ronson featuring Bruno Mars               "Uptown Funk"      2015
# 9                         Billie Eilish                   "Bad Guy"      2019
# 10                           Ed Sheeran         "Thinking Out Loud"      2015
# 11  Camila Cabello featuring Young Thug                    "Havana"      2017
# 12                            Lil Nas X             "Old Town Road"      2018
# 13                     Carly Rae Jepsen             "Call Me Maybe"      2011
# 14                         Taylor Swift                "Love Story"      2008
# 15                                Adele          "Someone Like You"      2011
# 16                              Rihanna                 "Needed Me"      2016
# 17      Shawn Mendes and Camila Cabello                  "Señorita"      2019
# 18                      Imagine Dragons               "Radioactive"      2012
# 19                      Imagine Dragons                  "Believer"      2017
# 20                                Drake                "God's Plan"      2018
#
#    Sales (in millions)        Source
# 0              41.5[a]      [47][48]
# 1              36.1[a]      [47][48]
# 2              32.5[a]          [49]
# 3              21.5[a]      [47][48]
# 4              21.4[a]      [47][48]
# 5              20.9[a]          [50]
# 6              20.7[a]      [51][47]
# 7                 20.6  [52][53][54]
# 8                20[a]          [50]
# 9              19.5[a]          [55]
# 10             19.5[a]          [50]
# 11             19.0[a]      [47][48]
# 12             18.4[a]          [55]
# 13                18.0          [56]
# 14             18.0[a]          [57]
# 15                17.0          [58]
# 16             17.0[a]          [49]
# 17             16.1[a]          [55]
# 18               16[a]          [59]
# 19             15.4[a]      [60][61]
# 20             15.3[a]          [48]

# %%
#add column for digital
df_digital['Phy/Dig'] = pd.Series(['Digital' for x in range(len(df_digital.index))])
df_digital
# Out:
#                                  Artist                      Single  Released  \
# 0                            Ed Sheeran              "Shape of You"      2017
# 1     Luis Fonsi featuring Daddy Yankee                 "Despacito"      2017
# 2               Rihanna featuring Drake                      "Work"      2016
# 3         The Chainsmokers and Coldplay  "Something Just Like This"      2017
# 4                            Ed Sheeran                   "Perfect"      2017
# 5    Wiz Khalifa featuring Charlie Puth             "See You Again"      2015
# 6     The Chainsmokers featuring Halsey                    "Closer"      2016
# 7                                 Adele       "Rolling in the Deep"      2011
# 8      Mark Ronson featuring Bruno Mars               "Uptown Funk"      2015
# 9                         Billie Eilish                   "Bad Guy"      2019
# 10                           Ed Sheeran         "Thinking Out Loud"      2015
# 11  Camila Cabello featuring Young Thug                    "Havana"      2017
# 12                            Lil Nas X             "Old Town Road"      2018
# 13                     Carly Rae Jepsen             "Call Me Maybe"      2011
# 14                         Taylor Swift                "Love Story"      2008
# 15                                Adele          "Someone Like You"      2011
# 16                              Rihanna                 "Needed Me"      2016
# 17      Shawn Mendes and Camila Cabello                  "Señorita"      2019
# 18                      Imagine Dragons               "Radioactive"      2012
# 19                      Imagine Dragons                  "Believer"      2017
# 20                                Drake                "God's Plan"      2018
#
#    Sales (in millions)        Source  Phy/Dig
# 0              41.5[a]      [47][48]  Digital
# 1              36.1[a]      [47][48]  Digital
# 2              32.5[a]          [49]  Digital
# 3              21.5[a]      [47][48]  Digital
# 4              21.4[a]      [47][48]  Digital
# 5              20.9[a]          [50]  Digital
# 6              20.7[a]      [51][47]  Digital
# 7                 20.6  [52][53][54]  Digital
# 8                20[a]          [50]  Digital
# 9              19.5[a]          [55]  Digital
# 10             19.5[a]          [50]  Digital
# 11             19.0[a]      [47][48]  Digital
# 12             18.4[a]          [55]  Digital
# 13                18.0          [56]  Digital
# 14             18.0[a]          [57]  Digital
# 15                17.0          [58]  Digital
# 16             17.0[a]          [49]  Digital
# 17             16.1[a]          [55]  Digital
# 18               16[a]          [59]  Digital
# 19             15.4[a]      [60][61]  Digital
# 20             15.3[a]          [48]  Digital

# %%
df_combined = pd.concat([df_physical, df_digital], axis=0)
df_combined
# Out:
#                                   Artist  \
# 0                            Bing Crosby
# 1                             Elton John
# 2                            Bing Crosby
# 3                             Tino Rossi
# 4                Bill Haley & His Comets
# 5                        Whitney Houston
# 6                          Elvis Presley
# 7                         USA for Africa
# 8                          The Ink Spots
# 9                            Celine Dion
# 10                          Mariah Carey
# 11                               Baccara
# 12                           Bryan Adams
# 13  John Travolta and Olivia Newton-John
# 0                             Ed Sheeran
# 1      Luis Fonsi featuring Daddy Yankee
# 2                Rihanna featuring Drake
# 3          The Chainsmokers and Coldplay
# 4                             Ed Sheeran
# 5     Wiz Khalifa featuring Charlie Puth
# 6      The Chainsmokers featuring Halsey
# 7                                  Adele
# 8       Mark Ronson featuring Bruno Mars
# 9                          Billie Eilish
# 10                            Ed Sheeran
# 11   Camila Cabello featuring Young Thug
# 12                             Lil Nas X
# 13                      Carly Rae Jepsen
# 14                          Taylor Swift
# 15                                 Adele
# 16                               Rihanna
# 17       Shawn Mendes and Camila Cabello
# 18                       Imagine Dragons
# 19                       Imagine Dragons
# 20                                 Drake
#
#                                                Single  Released  \
# 0                                   "White Christmas"      1942
# 1   "Something About the Way You Look Tonight"/"Ca...      1997
# 2                                      "Silent Night"      1935
# 3                                   "Petit Papa Noël"      1946
# 4                             "Rock Around the Clock"      1954
# 5                            "I Will Always Love You"      1992
# 6                                 "It's Now or Never"      1960
# 7                                  "We Are the World"      1985
# 8                                  "If I Didn't Care"      1939
# 9                               "My Heart Will Go On"      1997
# 10                  "All I Want For Christmas Is You"      1994
# 11                            "Yes Sir, I Can Boogie"      1977
# 12                "(Everything I Do) I Do It for You"      1991
# 13                       "You're the One That I Want"      1978
# 0                                      "Shape of You"      2017
# 1                                         "Despacito"      2017
# 2                                              "Work"      2016
# 3                          "Something Just Like This"      2017
# 4                                           "Perfect"      2017
# 5                                     "See You Again"      2015
# 6                                            "Closer"      2016
# 7                               "Rolling in the Deep"      2011
# 8                                       "Uptown Funk"      2015
# 9                                           "Bad Guy"      2019
# 10                                "Thinking Out Loud"      2015
# 11                                           "Havana"      2017
# 12                                    "Old Town Road"      2018
# 13                                    "Call Me Maybe"      2011
# 14                                       "Love Story"      2008
# 15                                 "Someone Like You"      2011
# 16                                        "Needed Me"      2016
# 17                                         "Señorita"      2019
# 18                                      "Radioactive"      2012
# 19                                         "Believer"      2017
# 20                                       "God's Plan"      2018
#
#        Sales (in millions)        Source   Phy/Dig
# 0                       50           [1]  Physical
# 1                       33           [1]  Physical
# 2                       30           [2]  Physical
# 3                       30           [3]  Physical
# 4                       25        [4][5]  Physical
# 5                       24        [6][7]  Physical
# 6                       20        [8][9]  Physical
# 7                       20          [10]  Physical
# 8   19[disputed – discuss]          [11]  Physical
# 9                       18          [12]  Physical
# 10                      16          [13]  Physical
# 11                      16          [14]  Physical
# 12                      15          [15]  Physical
# 13                      15          [16]  Physical
# 0                  41.5[a]      [47][48]   Digital
# 1                  36.1[a]      [47][48]   Digital
# 2                  32.5[a]          [49]   Digital
# 3                  21.5[a]      [47][48]   Digital
# 4                  21.4[a]      [47][48]   Digital
# 5                  20.9[a]          [50]   Digital
# 6                  20.7[a]      [51][47]   Digital
# 7                     20.6  [52][53][54]   Digital
# 8                    20[a]          [50]   Digital
# 9                  19.5[a]          [55]   Digital
# 10                 19.5[a]          [50]   Digital
# 11                 19.0[a]      [47][48]   Digital
# 12                 18.4[a]          [55]   Digital
# 13                    18.0          [56]   Digital
# 14                 18.0[a]          [57]   Digital
# 15                    17.0          [58]   Digital
# 16                 17.0[a]          [49]   Digital
# 17                 16.1[a]          [55]   Digital
# 18                   16[a]          [59]   Digital
# 19                 15.4[a]      [60][61]   Digital
# 20                 15.3[a]          [48]   Digital

# %%
#finding release at 2000
df_combined['Released'] == 2000

#closest to is "Something About the Way You Look Tonight" by Elton John	from 1997
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# Name: Released, dtype: bool

# %%
#seeing if I can also do it if it was a longer list

#find closest to 2000 and save the index
df_combined['diff_from_2000'] = abs(df_combined['Released'] - 2000)

# %%
#find the song with the smallest difference from 2000
min_diff_index = df_combined['diff_from_2000'].idxmin()

# %%
#get the column
df_combined.loc[min_diff_index, ['artist', 'song_title']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 #get the column
# ----> 2 df_combined.loc[min_diff_index, ['artist', 'song_title']]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1368, in _LocIndexer._getitem_tuple(self, tup)
#    1366 with suppress(IndexingError):
#    1367     tup = self._expand_ellipsis(tup)
# -> 1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
#    1371 tup = self._validate_tuple_indexer(tup)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1089, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1087             return section
#    1088         # This is an elided recursive call to iloc/loc
# -> 1089         return getattr(section, self.name)[new_key]
#    1091 raise IndexingError("not applicable")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1020, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#    1017 if com.is_null_slice(key):
#    1018     continue
# -> 1020 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1021 # We should never have retval.ndim < self.ndim, as that should
#    1022 #  be handled by the _getitem_lowerdim call above.
#    1023 assert retval.ndim == self.ndim
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['artist', 'song_title'], dtype='object')] are in the [columns]"

# %%
#same for year 2015

df_combined['Released'] == 2015

#gives true at 5, 8, and 10
#which are
#Wiz Khalifa featuring Charlie Puth	"See You Again"
#Mark Ronson featuring Bruno Mars	"Uptown Funk"
#Ed Sheeran	"Thinking Out Loud"
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8      True
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# Name: Released, dtype: bool

# %% [markdown]
# ## Space challenge
#
# 1. Make a single dataframe that combines the space missions from the 1950's to the 2020's
# 2. Write a script that returns the year with the most launches
# 3. Write a script that returns the most common month for launches
# 4. Write a script that ranks the months from most launches to fewest launches

# %%
# Starter code...

# %pip install lxml
import pandas as pd

rawdata_space = pd.read_html("https://en.wikipedia.org/wiki/Timeline_of_Solar_System_exploration")
# Out:
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (5.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
rawdata_space
# Out:
# [  Mission name        Launch date  \
#  0    Sputnik 1     4 October 1957
#  1    Sputnik 2    3 November 1957
#  2   Explorer 1    1 February 1958
#  3   Vanguard 1      17 March 1958
#  4       Luna 1     2 January 1959
#  5    Pioneer 4       3 March 1959
#  6       Luna 2  12 September 1959
#  7       Luna 3     4 October 1959
#
#                                           Description         Ref(s)
#  0                                First Earth orbiter         [1][2]
#  1  Earth orbiter, first animal in orbit, a dog na...      [2][3][4]
#  2  Earth orbiter; discovered Van Allen radiation ...            [5]
#  3  Earth orbiter; oldest spacecraft still in Eart...            [6]
#  4  First lunar flyby (attempted lunar impact?); f...  [7][8][9][10]
#  5                                        Lunar flyby       [11][12]
#  6  First extraterrestrial impact and lunar impact...       [10][13]
#  7  Lunar flyby; First images of another celestial...       [10][14]  ,
#     Mission name       Launch date  \
#  0     Pioneer 5     11 March 1960
#  1      Venera 1  12 February 1961
#  2      Vostok 1     12 April 1961
#  3      Ranger 1    23 August 1961
#  4      Ranger 2  18 November 1961
#  ..          ...               ...
#  68    Apollo 10       18 May 1969
#  69      Luna 15      13 July 1969
#  70    Apollo 11      16 July 1969
#  71       Zond 7     7 August 1969
#  72    Apollo 12  14 November 1969
#
#                                            Description  \
#  0                 Interplanetary space investigations
#  1   First probe to another planet; Venus flyby (co...
#  2           First crewed Earth orbiter (Yuri Gagarin)
#  3   Attempted lunar test flight (failed to leave E...
#  4   Attempted lunar test flight (failed to leave E...
#  ..                                                ...
#  68                               Crewed lunar orbiter
#  69               Second attempted lunar sample return
#  70  First crewed lunar landing and first successfu...
#  71                    Lunar flyby and return to Earth
#  72                               Crewed lunar landing
#
#                         Ref(s)
#  0                    [15][16]
#  1                [17][18][19]
#  2                    [20][21]
#  3                [22][23][24]
#  4                [24][25][26]
#  ..                        ...
#  68            [129][143][144]
#  69                 [145][146]
#  70  [147][148][149][150][151]
#  71             [46][152][153]
#  72            [154][155][156]
#
#  [73 rows x 4 columns],
#             Mission name        Launch date  \
#  0             Apollo 13      11 April 1970
#  1              Venera 7     17 August 1970
#  2               Luna 16  12 September 1970
#  3                Zond 8    20 October 1970
#  4    Luna 17/Lunokhod 1   10 November 1970
#  5             Apollo 14    31 January 1971
#  6              Salyut 1      19 April 1971
#  7                Mars 2        19 May 1971
#  8                Mars 3        28 May 1971
#  9             Mariner 9        30 May 1971
#  10            Apollo 15       26 July 1971
#  11              Luna 18   2 September 1971
#  12              Luna 19  28 September 1971
#  13              Luna 20   14 February 1972
#  14           Pioneer 10       3 March 1972
#  15             Venera 8      27 March 1972
#  16            Apollo 16      16 April 1972
#  17            Apollo 17    7 December 1972
#  18   Luna 21/Lunokhod 2     8 January 1973
#  19           Pioneer 11       5 April 1973
#  20  Explorer 49 (RAE-B)       10 June 1973
#  21               Mars 4       21 July 1973
#  22               Mars 5       25 July 1973
#  23               Mars 6      5 August 1973
#  24               Mars 7      9 August 1973
#  25           Mariner 10    3 November 1973
#  26              Luna 22        29 May 1974
#  27              Luna 23    28 October 1974
#  28             Helios-A   10 December 1974
#  29             Venera 9        8 June 1975
#  30            Venera 10       14 June 1975
#  31             Viking 1     20 August 1975
#  32             Viking 2   9 September 1975
#  33             Helios-B    15 January 1976
#  34              Luna 24      9 August 1976
#  35            Voyager 2     20 August 1977
#  36            Voyager 1   5 September 1977
#  37      Pioneer Venus 1        20 May 1978
#  38      Pioneer Venus 2      8 August 1978
#  39               ISEE-3     12 August 1978
#  40            Venera 11   9 September 1978
#  41            Venera 12  14 September 1978
#
#                                            Description  \
#  0   Crewed lunar flyby and return to Earth (crewed...
#  1   First Venus lander and the first spacecraft to...
#  2                   First robotic lunar sample return
#  3                     Lunar flyby and return to Earth
#  4                       First remote controlled rover
#  5                                Crewed lunar landing
#  6                                 First space station
#  7   First Mars impact, Mars orbiter and attempted ...
#  8   Mars orbiter, First Mars lander (first image t...
#  9                First to orbit another planet (Mars)
#  10     Crewed lunar landing; First crewed lunar rover
#  11  Attempted lunar sample return (crashed into Moon)
#  12                                      Lunar orbiter
#  13                        Lunar robotic sample return
#  14                                First Jupiter flyby
#  15                                       Venus lander
#  16                               Crewed lunar landing
#  17                          Last crewed lunar landing
#  18                                        Lunar rover
#  19               Jupiter flyby and First Saturn flyby
#  20                      Lunar orbiter/radio astronomy
#  21                Mars flyby (attempted Mars orbiter)
#  22                                       Mars orbiter
#  23  Mars flyby and attempted lander (failed due to...
#  24      Mars flyby and attempted lander (missed Mars)
#  25  Lunar and Venus flybys in addition to the Firs...
#  26                                      Lunar orbiter
#  27  Attempted lunar sample return (failed due to d...
#  28                                 Solar observations
#  29  First Venus orbiter and lander; First successf...
#  30                           Venus orbiter and lander
#  31  Mars orbiter and lander; First clear pictures ...
#  32                            Mars orbiter and lander
#  33                                 Solar observations
#  34                        Lunar robotic sample return
#  35    Jupiter/Saturn/first Uranus/first Neptune flyby
#  36  Jupiter/Saturn flyby, first to exit the helios...
#  37                                      Venus orbiter
#  38                           Venus atmospheric probes
#  39  Solar wind investigations; later redesignated ...
#  40                             Venus flyby and lander
#  41                             Venus flyby and lander
#
#                         Ref(s)
#  0        [157][158][159][160]
#  1              [18][161][162]
#  2                   [10][163]
#  3              [46][164][165]
#  4                   [10][166]
#  5             [167][168][169]
#  6                  [170][171]
#  7   [172][173][174][175][176]
#  8   [177][178][179][180][181]
#  9                  [182][183]
#  10       [129][184][185][186]
#  11                 [187][188]
#  12                      [189]
#  13                      [190]
#  14             [191][192][74]
#  15             [18][193][194]
#  16            [195][196][197]
#  17       [198][199][200][201]
#  18                      [202]
#  19             [74][203][204]
#  20                 [205][206]
#  21                 [207][208]
#  22                 [209][210]
#  23                 [211][212]
#  24                 [213][214]
#  25       [215][216][217][218]
#  26                  [10][219]
#  27                      [220]
#  28                 [221][222]
#  29        [18][223][224][225]
#  30        [18][226][227][228]
#  31       [229][230][231][232]
#  32       [232][233][234][235]
#  33                 [236][237]
#  34                  [10][238]
#  35            [239][240][241]
#  36            [241][242][243]
#  37                 [244][245]
#  38                 [246][247]
#  39            [248][249][250]
#  40        [18][251][252][253]
#  41        [18][254][255][256]  ,
#           Mission name       Launch date  \
#  0           Venera 13   30 October 1981
#  1           Venera 14   4 November 1981
#  2           Venera 15       2 June 1983
#  3           Venera 16       7 June 1983
#  4              Vega 1  15 December 1984
#  5              Vega 2  21 December 1984
#  6            Sakigake    8 January 1985
#  7              Giotto       2 July 1985
#  8   Suisei (Planet-A)    18 August 1985
#  9                 Mir  19 February 1986
#  10           Phobos 1       7 July 1988
#  11           Phobos 2      12 July 1988
#  12           Magellan        4 May 1989
#  13            Galileo   18 October 1989
#
#                                            Description  \
#  0   Venus flyby and lander. First recording of sou...
#  1                              Venus flyby and lander
#  2                                       Venus orbiter
#  3                                       Venus orbiter
#  4   Venus flyby, lander and first extraterrestrial...
#  5   Venus flyby, lander and balloon; continued on ...
#  6                                  Comet Halley flyby
#  7   First close observation of comet (distance 596...
#  8                                  Comet Halley flyby
#  9   First modular space station (operational 1986–...
#  10  Attempted Mars orbiter/Phobos landers (contact...
#  11  Mars orbiter/attempted Phobos landers (contact...
#  12                                      Venus orbiter
#  13  Venus flyby, first Asteroid flyby (Gaspra), fi...
#
#                         Ref(s)
#  0         [18][257][258][259]
#  1         [18][260][261][262]
#  2              [18][263][264]
#  3              [18][265][266]
#  4   [267][268][269][270][271]
#  5   [271][272][273][274][275]
#  6                  [276][277]
#  7             [278][279][280]
#  8                  [281][282]
#  9             [283][284][285]
#  10                 [286][287]
#  11                 [288][289]
#  12                 [290][291]
#  13       [292][293][294][295]  ,
#                              Mission name        Launch date  \
#  0                        Hiten (MUSES-A)    24 January 1990
#  1                 Hubble Space Telescope      24 April 1990
#  2                                Ulysses     6 October 1990
#  3                       Yohkoh (Solar-A)     30 August 1991
#  4                          Mars Observer  25 September 1992
#  5                             Clementine    25 January 1994
#  6                                   WIND    1 November 1994
#  7                                   SOHO    2 December 1995
#  8                         NEAR Shoemaker   17 February 1996
#  9                   Mars Global Surveyor    7 November 1996
#  10                               Mars 96   16 November 1996
#  11                       Mars Pathfinder    4 December 1996
#  12                                   ACE     25 August 1997
#  13                       Cassini–Huygens    15 October 1997
#  14                      Lunar Prospector     7 January 1998
#  15                     Nozomi (Planet-B)        3 July 1998
#  16                    Deep Space 1 (DS1)    24 October 1998
#  17                                   ISS   20 November 1998
#  18                  Mars Climate Orbiter   11 December 1998
#  19  Mars Polar Lander/Deep Space 2 (DS2)     3 January 1999
#  20                              Stardust    7 February 1999
#
#                                            Description  \
#  0                             Lunar flyby and orbiter
#  1   Orbital space telescope (operational since 199...
#  2                                 Solar polar orbiter
#  3                      Solar observations (1991–2001)
#  4               Attempted Mars orbiter (contact lost)
#  5   Lunar orbiter/attempted asteroid flyby (contac...
#  6                             Solar wind observations
#  7   Solar observatory (operational since 1996[need...
#  8   Eros orbiter, first near-Earth asteroid flyby,...
#  9                                        Mars orbiter
#  10  Attempted Mars orbiter/landers (failed to esca...
#  11   Mars lander and first successful planetary rover
#  12  Solar wind and "space weather" observations (o...
#  13  First Saturn orbiter and first outer planet mo...
#  14                                      Lunar orbiter
#  15  Attempted Mars orbiter (failed to enter Mars o...
#  16                           Asteroid and comet flyby
#  17                        International space station
#  18  Attempted Mars orbiter (orbit insertion failed...
#  19   Attempted Mars lander/penetrators (contact lost)
#  20  First comet coma sample return (returned 15 Ja...
#
#                         Ref(s)
#  0                  [296][297]
#  1             [298][299][300]
#  2             [301][302][303]
#  3                  [304][305]
#  4                  [306][307]
#  5             [308][309][310]
#  6                  [311][312]
#  7             [313][314][315]
#  8             [316][317][318]
#  9                  [319][320]
#  10                 [321][322]
#  11            [323][324][325]
#  12                 [326][327]
#  13  [328][329][330][331][332]
#  14                 [333][334]
#  15                 [335][336]
#  16                 [337][338]
#  17                 [339][340]
#  18                 [341][342]
#  19            [343][344][345]
#  20            [346][347][348]  ,
#                             Mission name        Launch date  \
#  0                     2001 Mars Odyssey       7 April 2001
#  1                               Genesis      8 August 2001
#  2                               CONTOUR        3 July 2002
#  3                    Hayabusa (MUSES-C)         9 May 2003
#  4                 Mars Express/Beagle 2        2 June 2003
#  5         Mars Exploration Rover Spirit       10 June 2003
#  6    Mars Exploration Rover Opportunity        8 July 2003
#  7                               SMART-1  27 September 2003
#  8                        Rosetta/Philae       2 March 2004
#  9                             MESSENGER      3 August 2004
#  10                          Deep Impact    12 January 2005
#  11          Mars Reconnaissance Orbiter     12 August 2005
#  12                        Venus Express    9 November 2005
#  13                         New Horizons    19 January 2006
#  14                     Hinode (Solar-B)  22 September 2006
#  15                               STEREO    26 October 2006
#  16                              Phoenix      4 August 2007
#  17                      SELENE (Kaguya)  14 September 2007
#  18                                 Dawn  27 September 2007
#  19                            Chang'e 1    24 October 2007
#  20                        Chandrayaan-1    22 October 2008
#  21           Herschel Space Observatory        14 May 2009
#  22  Lunar Reconnaissance Orbiter/LCROSS       18 June 2009
#  23                       WISE (NEOWISE)   14 December 2009
#
#                                            Description                Ref(s)
#  0                                        Mars orbiter            [349][350]
#  1                      First solar wind sample return  [351][352][353][354]
#  2   Attempted flyby of comet nuclei (Encke, Schwas...            [355][356]
#  3   Asteroid lander and first sample return from a...       [357][358][359]
#  4      Mars orbiter/attempted lander (lander failure)  [360][361][362][363]
#  5                                          Mars rover            [364][365]
#  6                                          Mars rover            [366][367]
#  7                                       Lunar orbiter            [368][369]
#  8   Asteroid Šteins and Lutetia flybys; first come...  [370][371][372][373]
#  9   First Mercury orbiter (Achieved orbit 18 March...       [374][375][376]
#  10                             Comet flyby and impact  [377][378][379][380]
#  11                                       Mars orbiter            [381][382]
#  12                                Venus polar orbiter            [383][384]
#  13  First Pluto/Charon flyby (on 14 July 2015); co...  [385][386][387][388]
#  14                                      Solar orbiter            [389][390]
#  15                     Two spacecraft, solar orbiters       [391][392][393]
#  16    Mars polar lander (Mars landing on 25 May 2008)            [394][395]
#  17                                     Lunar orbiters  [396][397][398][399]
#  18  Asteroid Ceres and Vesta orbiter (Entered orbi...       [400][401][402]
#  19                                      Lunar orbiter       [403][404][405]
#  20  Lunar orbiter and impactor; discovered water o...       [406][407][408]
#  21  Infrared space telescope at Sun–Earth L2 Lagra...            [409][410]
#  22             Lunar polar orbiter and lunar impactor  [411][412][413][414]
#  23  Infrared survey of celestial sky (WISE mission...       [415][416][417]  ,
#                                   Mission name        Launch date  \
#  0                  Solar Dynamics Observatory   11 February 2010
#  1                         Akatsuki (Planet-C)        20 May 2010
#  2                                      PICARD       15 June 2010
#  3                                   Chang'e 2     1 October 2010
#  4                                        Juno      5 August 2011
#  5                                       GRAIL  10 September 2011
#  6                   Fobos-Grunt and Yinghuo-1    8 November 2011
#  7   Mars Science Laboratory (Curiosity rover)   26 November 2011
#  8                     Van Allen Probes (RBSP)     30 August 2012
#  9                                        IRIS       28 June 2013
#  10                                      LADEE   7 September 2013
#  11                                     Hisaki  14 September 2013
#  12          Mars Orbiter Mission (Mangalyaan)    5 November 2013
#  13                                      MAVEN   18 November 2013
#  14                                  Chang'e 3    1 December 2013
#  15                               Chang'e 5-T1    23 October 2014
#  16                         Hayabusa2 / MASCOT    3 December 2014
#  17                                    PROCYON    3 December 2014
#  18                                     DSCOVR   11 February 2015
#  19   ExoMars Trace Gas Orbiter and EDM lander      14 March 2016
#  20                                 OSIRIS-REx   8 September 2016
#  21                                    InSight         5 May 2018
#  22                                    Queqiao        20 May 2018
#  23                         Parker Solar Probe     12 August 2018
#  24                                BepiColombo    19 October 2018
#  25                                  Chang'e 4    7 December 2018
#  26                                  Beresheet   22 February 2019
#  27                              Chandrayaan-2       22 July 2019
#
#                                            Description                Ref(s)
#  0                         Continuous solar monitoring            [418][419]
#  1   Venus orbiter (orbit insertion failed in 2010 ...       [420][421][422]
#  2                                    Solar monitoring            [423][424]
#  3         Lunar orbiter, asteroid 4179 Toutatis flyby       [405][425][426]
#  4                                     Jupiter orbiter            [427][428]
#  5                      Two spacecraft, Lunar orbiters       [429][430][431]
#  6   Attempted Phobos sample return and Mars orbite...            [432][433]
#  7                   Mars rover (landed 6 August 2012)            [434][435]
#  8               Earth Van Allen radiation belts study       [436][437][438]
#  9                                  Solar observations                 [439]
#  10                                      Lunar orbiter            [440][441]
#  11                   Planetary atmosphere observatory                 [442]
#  12                                       Mars orbiter       [443][444][445]
#  13                                       Mars orbiter            [446][447]
#  14  Lunar lander and rover (first lander since Sov...  [405][448][449][450]
#  15  Circumlunar mission and Earth reentry; technol...                 [451]
#  16  Asteroid lander and sample return (sample retu...       [359][452][453]
#  17  Comet observer and attempted asteroid flyby (e...                 [454]
#  18                                  Solar observation            [455][456]
#  19  Mars orbiter and attempted lander (lander fail...            [457][458]
#  20  Asteroid sample return mission (sample returne...            [459][460]
#  21                                        Mars lander            [461][462]
#  22  Relay satellite for Chang'e 4 in Halo orbit ar...                 [463]
#  23  Solar corona probe, closest solar approach (0....            [464][465]
#  24  Two Mercury orbiters (orbit insertion planned ...            [466][467]
#  25  Lunar lander and rover, first landing on the l...       [405][468][469]
#  26         Attempted lunar lander (crashed into Moon)            [470][471]
#  27  Lunar orbiter; attempted lander and rover (con...            [472][473]  ,
#                                           Mission name       Launch date  \
#  0                                       Solar Orbiter  10 February 2020
#  1                                           Mars Hope      19 July 2020
#  2                           Tianwen-1 (Zhurong rover)      23 July 2020
#  3   Mars 2020 (Perseverance rover and Ingenuity he...      30 July 2020
#  4                                           Chang'e 5  23 November 2020
#  5                                                Lucy   16 October 2021
#  6                                    DART / LICIACube  24 November 2021
#  7                          James Webb Space Telescope  25 December 2021
#  8                                            CAPSTONE      28 June 2022
#  9                                       Danuri (KPLO)     5 August 2022
#  10                          Artemis 1 and 10 cubesats  16 November 2022
#  11  Hakuto-R Mission 1 (Rashid rover) and Lunar Fl...  11 December 2022
#  12                                              JUICE     14 April 2023
#  13                                      Chandrayaan-3      14 July 2023
#  14                                            Luna 25    10 August 2023
#  15                                          Aditya-L1  2 September 2023
#  16                                SLIM (LEV-1, LEV-2)  6 September 2023
#  17                                             Psyche   13 October 2023
#  18  Peregrine Mission One (including Iris and Colm...    8 January 2024
#  19  IM-1 Nova-C Odysseus (including EagleCam deplo...  15 February 2024
#  20                                            DRO A/B     13 March 2024
#  21               Queqiao-2 (including Tiandu-1 and 2)     20 March 2024
#  22   Chang'e 6 (including Pakistan's ICUBE-Q cubesat)        3 May 2024
#
#                                            Description           Ref(s)
#  0                             Sun-observing satellite  [474][475][476]
#  1                                        Mars orbiter            [477]
#  2                     Mars orbiter, lander, and rover            [478]
#  3   Mars rover and helicopter drone; first powered...  [479][480][481]
#  4                                 Lunar sample return       [405][482]
#  5   Flyby of six Jupiter trojans and two main belt...       [483][484]
#  6   Asteroid 65803 Didymos flyby, asteroid moon Di...       [485][486]
#  7            Infrared space telescope at Sun–Earth L2       [487][488]
#  8                                       Lunar orbiter            [489]
#  9                                       Lunar orbiter            [490]
#  10  Uncrewed lunar orbital test of Orion spacecraf...            [491]
#  11  Lunar lander technology demonstration, lunar r...  [492][493][494]
#  12                           Jupiter/Ganymede orbiter            [495]
#  13  Lunar orbiter, lander and rover; first soft la...       [496][497]
#  14  Attempted lunar south pole lander (crashed int...       [498][499]
#  15           Sun-observing spacecraft at Sun–Earth L1            [500]
#  16                     Lunar flyby, lander and rovers       [501][502]
#  17                         Asteroid 16 Psyche orbiter            [503]
#  18        Lunar lander and rovers (landing precluded)            [504]
#  19                                      Lunar landers            [505]
#  20                                     Lunar orbiters            [506]
#  21                                     Lunar orbiters            [507]
#  22  Lunar sample return, rover and orbiters; first...       [508][509]  ,
#      vteSpaceflight lists and timelines  \
#  0              Timeline of spaceflight
#  1                              General
#  2                    Human spaceflight
#  3                              General
#  4                               Salyut
#  5                                  Mir
#  6                                  ISS
#  7                             Tiangong
#  8                              Shuttle
#  9                               People
#  10                                 EVA
#  11            Solar System exploration
#  12           Earth-orbiting satellites
#  13                            Vehicles
#  14             Launches by rocket type
#  15               Launches by spaceport
#  16  Agencies, companies and facilities
#  17   Other mission lists and timelines
#
#                   vteSpaceflight lists and timelines.1
#  0                             Timeline of spaceflight
#  1   Space exploration outline timeline Spacecraft ...
#  2   General Crewed spacecraft timeline by program ...
#  3   Crewed spacecraft timeline by program Spacefli...
#  4   Expeditions Spaceflights crewed uncrewed Space...
#  5   Expeditions ESA Spaceflights crewed uncrewed S...
#  6   Expeditions ESA Visiting Spaceflights crewed u...
#  7          Expeditions Crewed Spaceflights Spacewalks
#  8                            Crews Missions Rollbacks
#  9   Astronauts by name by year of selection Apollo...
#  10  1965–1999 2000–2014 2015–present Cumulative sp...
#  11  Timeline Interplanetary voyages Landings on ot...
#  12  Communications satellite firsts CubeSats Pocke...
#  13  Orbital launch systems Comparison Sounding roc...
#  14  Ariane Antares Atlas Atlas LV3B Atlas LV3C Bla...
#  15                                      Satish Dhawan
#  16  Communications satellite companies comparison ...
#  17  First orbital launches by country First satell...  ,
#            0                                                  1
#  0   General  Crewed spacecraft timeline by program Spacefli...
#  1    Salyut  Expeditions Spaceflights crewed uncrewed Space...
#  2       Mir  Expeditions ESA Spaceflights crewed uncrewed S...
#  3       ISS  Expeditions ESA Visiting Spaceflights crewed u...
#  4  Tiangong         Expeditions Crewed Spaceflights Spacewalks
#  5   Shuttle                           Crews Missions Rollbacks
#  6    People  Astronauts by name by year of selection Apollo...
#  7       EVA  1965–1999 2000–2014 2015–present Cumulative sp...,
#       vteExploration of the Solar System  \
#  0  Timeline of Solar System exploration
#  1                        Exploration of
#  2                    Artificial objects
#  3         On extra-terrestrial surfaces
#  4                   Deep-space missions
#  5                                 Lists
#  6    Space exploration outline timeline
#
#                  vteExploration of the Solar System.1
#  0               Timeline of Solar System exploration
#  1  Mercury Venus Moon Mars Jupiter Saturn Uranus ...
#  2  On extra-terrestrial surfaces Moon Venus Mars ...
#  3                              Moon Venus Mars Titan
#  4        Heliocentric orbit Leaving the Solar System
#  5  Solar System probes Minor planets and comets v...
#  6                 Space exploration outline timeline  ,
#                                 0                                            1
#  0  On extra-terrestrial surfaces                        Moon Venus Mars Titan
#  1            Deep-space missions  Heliocentric orbit Leaving the Solar System,
#                vteNASA planetary exploration programs  \
#  0                                             Active
#  1  Large strategic science missions Lunar Discove...
#  2                                          Completed
#  3                                          Cancelled
#  4                              List of NASA missions
#
#              vteNASA planetary exploration programs.1
#  0  Large strategic science missions Lunar Discove...
#  1  Large strategic science missions Lunar Discove...
#  2  Lunar Orbiter Lunar Precursor Mariner MESUR Ne...
#  3  Grand Tour Mariner Mark II Project Prometheus ...
#  4                              List of NASA missions  ,
#                                                     0  \
#  0  Large strategic science missions Lunar Discove...
#
#                                                     1
#  0  Large strategic science missions Lunar Discove...  ,
#                                        vteSolar System  \
#  0   Sun Mercury Venus Earth Mars Ceres Jupiter Sat...
#  1   Planets, dwarfs Terrestrials Mercury Venus Ear...
#  2   Planets, dwarfs Terrestrials Mercury Venus Ear...
#  3                                     Planets, dwarfs
#  4                                               Moons
#  5                                               Rings
#  6                           Small Solar System bodies
#  7                                Hypothetical objects
#  8                               Exploration (outline)
#  9                                Formation, evolution
#  10                                              Lists
#  11                                            Related
#  12  Outline of the Solar System  Solar System port...
#
#                                      vteSolar System.1
#  0   Sun Mercury Venus Earth Mars Ceres Jupiter Sat...
#  1   Planets, dwarfs Terrestrials Mercury Venus Ear...
#  2   Hypothetical objects Fifth giant Nemesis Phaet...
#  3   Terrestrials Mercury Venus Earth Mars Giants G...
#  4   Earth Moon other near-Earth objects Mars Phobo...
#  5   Earth? Jovian Saturnian (Rhean?) Charikloan Ch...
#  6   Comets Damocloids Meteoroids Minor planets nam...
#  7   Fifth giant Nemesis Phaeton Planet Nine Planet...
#  8   Colonization Discovery astronomy historical mo...
#  9   Star formation Accretion Accretion disk Excret...
#  10  Comets Possible dwarf planets Gravitationally ...
#  11  Double planet Lagrangian points Moonlets Syzyg...
#  12  Outline of the Solar System  Solar System port...  ,
#                                                     0  \
#  0  Planets, dwarfs Terrestrials Mercury Venus Ear...
#  1                                    Planets, dwarfs
#  2                                              Moons
#  3                                              Rings
#  4                          Small Solar System bodies
#  5                               Hypothetical objects
#  6                              Exploration (outline)
#  7                               Formation, evolution
#  8                                              Lists
#  9                                            Related
#
#                                                     1
#  0  Hypothetical objects Fifth giant Nemesis Phaet...
#  1  Terrestrials Mercury Venus Earth Mars Giants G...
#  2  Earth Moon other near-Earth objects Mars Phobo...
#  3  Earth? Jovian Saturnian (Rhean?) Charikloan Ch...
#  4  Comets Damocloids Meteoroids Minor planets nam...
#  5  Fifth giant Nemesis Phaeton Planet Nine Planet...
#  6  Colonization Discovery astronomy historical mo...
#  7  Star formation Accretion Accretion disk Excret...
#  8  Comets Possible dwarf planets Gravitationally ...
#  9  Double planet Lagrangian points Moonlets Syzyg...  ,
#                             0  \
#  0            Planets, dwarfs
#  1                      Moons
#  2                      Rings
#  3  Small Solar System bodies
#
#                                                     1
#  0  Terrestrials Mercury Venus Earth Mars Giants G...
#  1  Earth Moon other near-Earth objects Mars Phobo...
#  2  Earth? Jovian Saturnian (Rhean?) Charikloan Ch...
#  3  Comets Damocloids Meteoroids Minor planets nam...  ,
#                         0                                                  1
#  0   Hypothetical objects  Fifth giant Nemesis Phaeton Planet Nine Planet...
#  1  Exploration (outline)  Colonization Discovery astronomy historical mo...
#  2   Formation, evolution  Star formation Accretion Accretion disk Excret...
#  3                  Lists  Comets Possible dwarf planets Gravitationally ...
#  4                Related  Double planet Lagrangian points Moonlets Syzyg...]

# %%
#combining the 8 dataframes as seen on the website
df_space_combined = pd.concat(rawdata_space[0:8])
df_space_combined
# Out:
#                                          Mission name       Launch date  \
# 0                                           Sputnik 1    4 October 1957
# 1                                           Sputnik 2   3 November 1957
# 2                                          Explorer 1   1 February 1958
# 3                                          Vanguard 1     17 March 1958
# 4                                              Luna 1    2 January 1959
# ..                                                ...               ...
# 18  Peregrine Mission One (including Iris and Colm...    8 January 2024
# 19  IM-1 Nova-C Odysseus (including EagleCam deplo...  15 February 2024
# 20                                            DRO A/B     13 March 2024
# 21               Queqiao-2 (including Tiandu-1 and 2)     20 March 2024
# 22   Chang'e 6 (including Pakistan's ICUBE-Q cubesat)        3 May 2024
#
#                                           Description         Ref(s)
# 0                                 First Earth orbiter         [1][2]
# 1   Earth orbiter, first animal in orbit, a dog na...      [2][3][4]
# 2   Earth orbiter; discovered Van Allen radiation ...            [5]
# 3   Earth orbiter; oldest spacecraft still in Eart...            [6]
# 4   First lunar flyby (attempted lunar impact?); f...  [7][8][9][10]
# ..                                                ...            ...
# 18        Lunar lander and rovers (landing precluded)          [504]
# 19                                      Lunar landers          [505]
# 20                                     Lunar orbiters          [506]
# 21                                     Lunar orbiters          [507]
# 22  Lunar sample return, rover and orbiters; first...     [508][509]
#
# [233 rows x 4 columns]

# %%
#create new column with launch year
df_space_combined['Launch_year'] = df_space_combined['Launch date'].str.extract(r'(\d{4})')
df_space_combined
# Out:
#                                          Mission name       Launch date  \
# 0                                           Sputnik 1    4 October 1957
# 1                                           Sputnik 2   3 November 1957
# 2                                          Explorer 1   1 February 1958
# 3                                          Vanguard 1     17 March 1958
# 4                                              Luna 1    2 January 1959
# ..                                                ...               ...
# 18  Peregrine Mission One (including Iris and Colm...    8 January 2024
# 19  IM-1 Nova-C Odysseus (including EagleCam deplo...  15 February 2024
# 20                                            DRO A/B     13 March 2024
# 21               Queqiao-2 (including Tiandu-1 and 2)     20 March 2024
# 22   Chang'e 6 (including Pakistan's ICUBE-Q cubesat)        3 May 2024
#
#                                           Description         Ref(s)  \
# 0                                 First Earth orbiter         [1][2]
# 1   Earth orbiter, first animal in orbit, a dog na...      [2][3][4]
# 2   Earth orbiter; discovered Van Allen radiation ...            [5]
# 3   Earth orbiter; oldest spacecraft still in Eart...            [6]
# 4   First lunar flyby (attempted lunar impact?); f...  [7][8][9][10]
# ..                                                ...            ...
# 18        Lunar lander and rovers (landing precluded)          [504]
# 19                                      Lunar landers          [505]
# 20                                     Lunar orbiters          [506]
# 21                                     Lunar orbiters          [507]
# 22  Lunar sample return, rover and orbiters; first...     [508][509]
#
#    Launch_year
# 0         1957
# 1         1957
# 2         1958
# 3         1958
# 4         1959
# ..         ...
# 18        2024
# 19        2024
# 20        2024
# 21        2024
# 22        2024
#
# [233 rows x 5 columns]

# %%
#most launches, year
df_space_combined['Launch_year'].value_counts(normalize=False)
# Out:
# Launch_year
# 1965    12
# 1967    12
# 1966    11
# 1969    10
# 1968     9
#         ..
# 1995     1
# 2002     1
# 2015     1
# 2008     1
# 2012     1
# Name: count, Length: 61, dtype: int64

# %%
most_launches_year = df_space_combined['Launch_year'].mode()
most_launches_year
# Out:
# 0    1965
# 1    1967
# Name: Launch_year, dtype: object

# %%
#most launches, month
#make a new column for launch month
df_space_combined['Launch_month'] = df_space_combined['Launch date'].str.extract(r'([A-Za-z]+)')
df_space_combined
# Out:
#                                          Mission name       Launch date  \
# 0                                           Sputnik 1    4 October 1957
# 1                                           Sputnik 2   3 November 1957
# 2                                          Explorer 1   1 February 1958
# 3                                          Vanguard 1     17 March 1958
# 4                                              Luna 1    2 January 1959
# ..                                                ...               ...
# 18  Peregrine Mission One (including Iris and Colm...    8 January 2024
# 19  IM-1 Nova-C Odysseus (including EagleCam deplo...  15 February 2024
# 20                                            DRO A/B     13 March 2024
# 21               Queqiao-2 (including Tiandu-1 and 2)     20 March 2024
# 22   Chang'e 6 (including Pakistan's ICUBE-Q cubesat)        3 May 2024
#
#                                           Description         Ref(s)  \
# 0                                 First Earth orbiter         [1][2]
# 1   Earth orbiter, first animal in orbit, a dog na...      [2][3][4]
# 2   Earth orbiter; discovered Van Allen radiation ...            [5]
# 3   Earth orbiter; oldest spacecraft still in Eart...            [6]
# 4   First lunar flyby (attempted lunar impact?); f...  [7][8][9][10]
# ..                                                ...            ...
# 18        Lunar lander and rovers (landing precluded)          [504]
# 19                                      Lunar landers          [505]
# 20                                     Lunar orbiters          [506]
# 21                                     Lunar orbiters          [507]
# 22  Lunar sample return, rover and orbiters; first...     [508][509]
#
#    Launch_year Launch_month
# 0         1957      October
# 1         1957     November
# 2         1958     February
# 3         1958        March
# 4         1959      January
# ..         ...          ...
# 18        2024      January
# 19        2024     February
# 20        2024        March
# 21        2024        March
# 22        2024          May
#
# [233 rows x 6 columns]

# %%
#3. Write a script that returns the most common month for launches
df_space_combined['Launch_month'].value_counts(normalize=False).head(1)
# Out:
# Launch_month
# November    30
# Name: count, dtype: int64

# %%
#4. Write a script that ranks the months from most launches to fewest launches
df_space_combined['Launch_month'].value_counts(normalize=False)
# Out:
# Launch_month
# November     30
# August       27
# September    22
# October      22
# July         21
# January      19
# December     19
# May          17
# March        15
# February     14
# June         14
# April        13
# Name: count, dtype: int64

# %% [markdown]
# ## Supervillain challenge
#
# 1. Write a script that combines the tables showing supervillain debuts from the 30's through the 2010's
# 2. Write a script that ranks each decade in terms of how many supervillains debuted in that decade
# 3. Write a script that ranks the different comics companies in terms of how many supervillains they have, and display the results in a nice table (pandas dataframe)

# %%
rawdata_villians = pd.read_html("https://en.wikipedia.org/wiki/List_of_comic_book_supervillain_debuts")
#rawdata_villians

# %%
#1. Write a script that combines the tables showing supervillain debuts from the 30's through the 2010's

df_villians_combined = pd.concat(rawdata_villians[3:12])
df_villians_combined
# Out:
#             Character / Team      Year Debuted                   Company  \
# 0             Ultra-Humanite       1939 (June)                        DC
# 1                  Dr. Death       1939 (July)                        DC
# 2                   The Monk  1939 (September)                        DC
# 3                   The Claw   1939 (December)  Lev Gleason Publications
# 0                   Hath-Set    1940 (January)                        DC
# ..                       ...               ...                       ...
# 4                  Bloodwork     2016 (August)                        DC
# 5                   Godspeed     2016 (August)                        DC
# 6   The Hamster (Mr. Hansen)              2017           Disney/Hyperion
# 7            The Underhander              2019           Disney/Hyperion
# 8             The Cocodrilos              2019           Disney/Hyperion
#
#                                      Creator/s  \
# 0                    Jerry Siegel, Joe Shuster
# 1                        Bob Kane, Bill Finger
# 2                        Bob Kane, Bill Finger
# 3                                    Jack Cole
# 0                  Gardner Fox, Dennis Neville
# ..                                         ...
# 4                             Brian Buccellato
# 5   Joshua Williamson, Carmine Di Giandomenico
# 6                                Rhode Montijo
# 7                                Rhode Montijo
# 8                                Rhode Montijo
#
#                                First Appearance
# 0                    Action Comics (vol. 1) #13
# 1                 Detective Comics (vol. 1) #29
# 2                 Detective Comics (vol. 1) #31
# 3                       Silver Streak Comics #1
# 0                               Flash Comics #1
# ..                                          ...
# 4                                 The Flash #28
# 5                         The Flash: Rebirth #1
# 6       The Gumazing Gum Girl! Book 2: Gum Luck
# 7   The Gumazing Gum Girl! Book 4: Cover Blown!
# 8   The Gumazing Gum Girl! Book 4: Cover Blown!
#
# [636 rows x 5 columns]

# %%
#2. Write a script that ranks each decade in terms of how many supervillains debuted in that decade

#split the debut year from the month
df_villians_combined['Debut year only'] = df_villians_combined['Year Debuted'].str.extract(r'(\d{4})')
df_villians_combined
# Out:
#             Character / Team      Year Debuted                   Company  \
# 0             Ultra-Humanite       1939 (June)                        DC
# 1                  Dr. Death       1939 (July)                        DC
# 2                   The Monk  1939 (September)                        DC
# 3                   The Claw   1939 (December)  Lev Gleason Publications
# 0                   Hath-Set    1940 (January)                        DC
# ..                       ...               ...                       ...
# 4                  Bloodwork     2016 (August)                        DC
# 5                   Godspeed     2016 (August)                        DC
# 6   The Hamster (Mr. Hansen)              2017           Disney/Hyperion
# 7            The Underhander              2019           Disney/Hyperion
# 8             The Cocodrilos              2019           Disney/Hyperion
#
#                                      Creator/s  \
# 0                    Jerry Siegel, Joe Shuster
# 1                        Bob Kane, Bill Finger
# 2                        Bob Kane, Bill Finger
# 3                                    Jack Cole
# 0                  Gardner Fox, Dennis Neville
# ..                                         ...
# 4                             Brian Buccellato
# 5   Joshua Williamson, Carmine Di Giandomenico
# 6                                Rhode Montijo
# 7                                Rhode Montijo
# 8                                Rhode Montijo
#
#                                First Appearance Debut year only
# 0                    Action Comics (vol. 1) #13            1939
# 1                 Detective Comics (vol. 1) #29            1939
# 2                 Detective Comics (vol. 1) #31            1939
# 3                       Silver Streak Comics #1            1939
# 0                               Flash Comics #1            1940
# ..                                          ...             ...
# 4                                 The Flash #28            2016
# 5                         The Flash: Rebirth #1            2016
# 6       The Gumazing Gum Girl! Book 2: Gum Luck            2017
# 7   The Gumazing Gum Girl! Book 4: Cover Blown!            2019
# 8   The Gumazing Gum Girl! Book 4: Cover Blown!            2019
#
# [636 rows x 6 columns]

# %%
#split of digit number 3 from the rest of the year
df_villians_combined['Third digit of year'] = df_villians_combined['Debut year only'].str[2]
df_villians_combined

#I guess this works for now as the years are less than 100 apart, if there were both 1910 and 2010 it would count these as the same year
# Out:
#             Character / Team      Year Debuted                   Company  \
# 0             Ultra-Humanite       1939 (June)                        DC
# 1                  Dr. Death       1939 (July)                        DC
# 2                   The Monk  1939 (September)                        DC
# 3                   The Claw   1939 (December)  Lev Gleason Publications
# 0                   Hath-Set    1940 (January)                        DC
# ..                       ...               ...                       ...
# 4                  Bloodwork     2016 (August)                        DC
# 5                   Godspeed     2016 (August)                        DC
# 6   The Hamster (Mr. Hansen)              2017           Disney/Hyperion
# 7            The Underhander              2019           Disney/Hyperion
# 8             The Cocodrilos              2019           Disney/Hyperion
#
#                                      Creator/s  \
# 0                    Jerry Siegel, Joe Shuster
# 1                        Bob Kane, Bill Finger
# 2                        Bob Kane, Bill Finger
# 3                                    Jack Cole
# 0                  Gardner Fox, Dennis Neville
# ..                                         ...
# 4                             Brian Buccellato
# 5   Joshua Williamson, Carmine Di Giandomenico
# 6                                Rhode Montijo
# 7                                Rhode Montijo
# 8                                Rhode Montijo
#
#                                First Appearance Debut year only  \
# 0                    Action Comics (vol. 1) #13            1939
# 1                 Detective Comics (vol. 1) #29            1939
# 2                 Detective Comics (vol. 1) #31            1939
# 3                       Silver Streak Comics #1            1939
# 0                               Flash Comics #1            1940
# ..                                          ...             ...
# 4                                 The Flash #28            2016
# 5                         The Flash: Rebirth #1            2016
# 6       The Gumazing Gum Girl! Book 2: Gum Luck            2017
# 7   The Gumazing Gum Girl! Book 4: Cover Blown!            2019
# 8   The Gumazing Gum Girl! Book 4: Cover Blown!            2019
#
#    Third digit of year
# 0                    3
# 1                    3
# 2                    3
# 3                    3
# 0                    4
# ..                 ...
# 4                    1
# 5                    1
# 6                    1
# 7                    1
# 8                    1
#
# [636 rows x 7 columns]

# %%
#making a column with the decade just to be clear that e.g. 3 is not a decade :)))
df_villians_combined['Decade'] = df_villians_combined['Third digit of year'] + '0'
df_villians_combined

#this could probably be done with just one line:
df_villians_combined['Decade'] = df_villians_combined['Debut year only'].str[2] + '0'
df_villians_combined
# Out:
#             Character / Team      Year Debuted                   Company  \
# 0             Ultra-Humanite       1939 (June)                        DC
# 1                  Dr. Death       1939 (July)                        DC
# 2                   The Monk  1939 (September)                        DC
# 3                   The Claw   1939 (December)  Lev Gleason Publications
# 0                   Hath-Set    1940 (January)                        DC
# ..                       ...               ...                       ...
# 4                  Bloodwork     2016 (August)                        DC
# 5                   Godspeed     2016 (August)                        DC
# 6   The Hamster (Mr. Hansen)              2017           Disney/Hyperion
# 7            The Underhander              2019           Disney/Hyperion
# 8             The Cocodrilos              2019           Disney/Hyperion
#
#                                      Creator/s  \
# 0                    Jerry Siegel, Joe Shuster
# 1                        Bob Kane, Bill Finger
# 2                        Bob Kane, Bill Finger
# 3                                    Jack Cole
# 0                  Gardner Fox, Dennis Neville
# ..                                         ...
# 4                             Brian Buccellato
# 5   Joshua Williamson, Carmine Di Giandomenico
# 6                                Rhode Montijo
# 7                                Rhode Montijo
# 8                                Rhode Montijo
#
#                                First Appearance Debut year only  \
# 0                    Action Comics (vol. 1) #13            1939
# 1                 Detective Comics (vol. 1) #29            1939
# 2                 Detective Comics (vol. 1) #31            1939
# 3                       Silver Streak Comics #1            1939
# 0                               Flash Comics #1            1940
# ..                                          ...             ...
# 4                                 The Flash #28            2016
# 5                         The Flash: Rebirth #1            2016
# 6       The Gumazing Gum Girl! Book 2: Gum Luck            2017
# 7   The Gumazing Gum Girl! Book 4: Cover Blown!            2019
# 8   The Gumazing Gum Girl! Book 4: Cover Blown!            2019
#
#    Third digit of year Decade AAADecade
# 0                    3     30        30
# 1                    3     30        30
# 2                    3     30        30
# 3                    3     30        30
# 0                    4     40        40
# ..                 ...    ...       ...
# 4                    1     10        10
# 5                    1     10        10
# 6                    1     10        10
# 7                    1     10        10
# 8                    1     10        10
#
# [636 rows x 9 columns]

# %%
df_villians_combined['Decade'].value_counts(normalize=False)
# Out:
# Decade
# 60    228
# 70     97
# 80     92
# 90     84
# 00     49
# 40     47
# 50     26
# 10      9
# 30      4
# Name: count, dtype: int64

# %%
# 3. Write a script that ranks the different comics companies in terms of how many supervillains they have, and display the results in a nice table (pandas dataframe)
 #do the same but for companies

company_rank = df_villians_combined['Company'].value_counts(normalize=False)

# %%
company_rank = df_villians_combined['Company'].value_counts(normalize=False).reset_index()
company_rank.columns = ['Company', 'Number of super villians']
company_rank
# Out:
#                      Company  Number of super villians
# 0                         DC                       338
# 1                     Marvel                       264
# 2          Fawcett Comics/DC                         6
# 3                      Image                         5
# 4                 Dark Horse                         5
# 5              Marvel/Timely                         4
# 6            Disney/Hyperion                         4
# 7                   Eternity                         3
# 8   Lev Gleason Publications                         1
# 9                     Comico                         1
# 10                    Mirage                         1
# 11              Image Comics                         1

# %% [markdown]
# ## Stroop challenge
#
# Every year between 2015 and 2021, the students in my Language, Cognition, and the Brain course participated in a version of the Stroop task. Using a stopwatch (ok, using their phones), they recorded how fast they could say a list of things (either reading or naming colors or color words). The column names mean "Reading with No Interference", "Naming with Interference", "Naming with No Interference", and "Reading with Interference". The times are in seconds.
#
# ### Stroop challenge 1:
# Transform these data from wide format to long format, so that the result is a dataframe with
# - 1 column named "Participant_id" with a unique number for each participant (you can use the row indices)
# - 1 column named "Year" with the year data
# - 1 column named "Task" that shows which task they were doing
# - 1 column named "RT" that shows their response time

# %%
# Starter code 1...

df = pd.read_csv("https://raw.githubusercontent.com/ethanweed/Stroop/master/Stroop-raw-over-the-years.csv")
df.head()
# Out:
#    Reading_NoInt  Naming_Int  Naming_NoInt  Reading_Int  Year
# 0           4.16        6.76          4.45         4.65  2015
# 1           4.35        7.73          4.78         4.46  2015
# 2           3.60        7.00          4.00         3.50  2015
# 3           3.90        9.03          4.60         6.30  2015
# 4           4.22        9.98          6.83         6.24  2015

# %%
# Starter code 2...

# Make a new column using the dataframe indices as particpant numbers

df.index.name = 'Participant_id'
df = df.reset_index()

#df.reset_index(inplace = True)
# NOTE: This line does exactly the same thing as the line above:
# it replaces the original df with a new df with the updated index. That's what
# "inplace = True" means. Or, you can just assign the dataframe with the updated index
# to a new dataframe with the same name as the old dataframe, which is what I did above.
# The end result is the same.

df
# Out:
#      Participant_id  Reading_NoInt  Naming_Int  Naming_NoInt  Reading_Int  \
# 0                 0           4.16        6.76          4.45         4.65
# 1                 1           4.35        7.73          4.78         4.46
# 2                 2           3.60        7.00          4.00         3.50
# 3                 3           3.90        9.03          4.60         6.30
# 4                 4           4.22        9.98          6.83         6.24
# ..              ...            ...         ...           ...          ...
# 177             177           4.30        7.08          6.25         4.28
# 178             178           4.75        9.66          6.12         5.49
# 179             179           4.98        7.52          6.73         5.16
# 180             180           5.16        8.81          8.19         5.51
# 181             181           4.27       10.40          5.32         4.59
#
#      Year
# 0    2015
# 1    2015
# 2    2015
# 3    2015
# 4    2015
# ..    ...
# 177  2021
# 178  2021
# 179  2021
# 180  2021
# 181  2021
#
# [182 rows x 6 columns]

# %%
df_melt = pd.melt(df, id_vars=['Participant_id', 'Year'], value_vars=['Reading_NoInt', 'Naming_Int', 'Naming_NoInt', 'Reading_Int'], var_name='Task', value_name='RT', col_level=None, ignore_index=True)
df_melt
#df_melt.head()
# Out:
#      Participant_id  Year           Task    RT
# 0                 0  2015  Reading_NoInt  4.16
# 1                 1  2015  Reading_NoInt  4.35
# 2                 2  2015  Reading_NoInt  3.60
# 3                 3  2015  Reading_NoInt  3.90
# 4                 4  2015  Reading_NoInt  4.22
# ..              ...   ...            ...   ...
# 723             177  2021    Reading_Int  4.28
# 724             178  2021    Reading_Int  5.49
# 725             179  2021    Reading_Int  5.16
# 726             180  2021    Reading_Int  5.51
# 727             181  2021    Reading_Int  4.59
#
# [728 rows x 4 columns]

# %% [markdown]
# ## Stroop challenge 2 (Advanced!!!):
#
# Make a new dataframe which shows the mean response time (in seconds) for each task for each year.

# %%
#.mean()

#year - mean RT
#2015
#2016

#pd.df_melt.mean(axis='Year', skipna=True, numeric_only=False)

#df_melt.mean('Year')


mean_year_task = df_melt.groupby(['Year', 'Task'])['RT'].mean()
mean_year_task
# Out:
# Year  Task
# 2015  Naming_Int        8.617143
#       Naming_NoInt      5.123571
#       Reading_Int       4.446429
#       Reading_NoInt     3.951429
# 2016  Naming_Int        8.859268
#       Naming_NoInt      5.405610
#       Reading_Int       5.340000
#       Reading_NoInt     4.076098
# 2017  Naming_Int        9.311765
#       Naming_NoInt      5.771176
#       Reading_Int       5.492353
#       Reading_NoInt     4.414412
# 2018  Naming_Int        9.372667
#       Naming_NoInt      5.298000
#       Reading_Int       4.938667
#       Reading_NoInt     3.886000
# 2019  Naming_Int        9.536087
#       Naming_NoInt      6.345652
#       Reading_Int       6.090870
#       Reading_NoInt     4.935652
# 2020  Naming_Int        9.740833
#       Naming_NoInt      5.962500
#       Reading_Int       4.956667
#       Reading_NoInt     4.395000
# 2021  Naming_Int       10.105484
#       Naming_NoInt      6.387742
#       Reading_Int       7.038065
#       Reading_NoInt     4.842581
# Name: RT, dtype: float64
